# %%
#importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading data 
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#data cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10) # Sample method for sampling out dataset
# Out:
#               job_title_short  \
# 421025           Data Analyst
# 444601       Business Analyst
# 186238          Data Engineer
# 48000   Senior Data Scientist
# 738169      Software Engineer
# 133316         Data Scientist
# 359033           Data Analyst
# 327168           Data Analyst
# 350366       Business Analyst
# 554503         Data Scientist
#
#                                                 job_title  \
# 421025                             Data Analyst (m, f, d)
# 444601                                HR Business Analyst
# 186238                               Middle Data Engineer
# 48000                               Data Scientist Senior
# 738169                                   Product Engineer
# 133316                                     Data Scientist
# 359033  Online Data Analyst - Japan at TELUS Internati...
# 327168       Data and Analytics Expert Operations (f/m/d)
# 350366                       Principal Engineer, Hardware
# ...

# %%
df.sample(10, random_state= 42) # sample method with assigning random state for not to change the sample  on every iteration
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy() # copy method for creating a copy of orginal fataset for further calculations

# %%
df_altered['salary_year_avg'].median() # median of the slary year column of the new copy dataframe
# Out:
# 115000.0

# %%
# Entering the new medain for the rest of the NAN values of the Salary year column 
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
# the original data frame is intact, we have made calculations only in the df_altered dataframe

df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
